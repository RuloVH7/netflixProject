# %% [markdown]
# # Netflix Project
# By: Raúl Reyna Hernández

# %% [markdown]
# Have you ever wondered what lies beneath the surface of Netflix's vast content library? Through meticulous data examination and visualizations, we aim to uncover fascinating insights into producer's visions, genre preferences, and the secrets behind Netflix's success. So, are you ready to dive deep into the world of EDA and unravel the mysteries of Netflix's streaming data? Let's embark on this data-driven adventure together and see what captivating stories the numbers have to tell!

# %%
# Setting the first stage of our project it is necessary to fecth the essential libraries to conduct the EDA.
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Importing the dataset.
netflix_data = pd.read_csv(r"C:\Users\raul_\OneDrive\Documentos\PythonFolder\DataAnalysiswithJupyter\NetflixProject\8. Netflix Dataset.csv")

# %%
#Reviewing the dataframe.
netflix_data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# # GETTING GENERAL INSIGHTS OF THE DATFRAME

# %%
# Show first top-5 records from the dataframe.
netflix_data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# Show bottom 5 records from the Dataset.
netflix_data.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
# Show number of rows and number of columns from the dataframe.
netflix_data.shape
# Out:
# (7789, 11)

# %%
# No. Of total values existing in the dataset.
netflix_data.size
# Out:
# 85679

# %%
# Show column names from the dataframe.
netflix_data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
# Show the the type of data from each column.
netflix_data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
# Show general information of the dataframe.

# Column index number, Column  name, null values on each column, data type, memory usage
netflix_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# # TASK 1: Is there any duplicate record in this dataset? If so, remove the duplicate ones

# %%
#First is needed to now how many rows exist in the dataframe 
netflix_data.shape
# Out:
# (7789, 11)

# %%
# .duplicated() command computes the boolean Series indicating duplicate rows in the netflix_data.

# Using the index will return the duplicated records.
netflix_data[netflix_data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
# drop_duplicates() method is used to remove duplicate rows from a pandas DataFrame.

# inplace=True will keep the changes on the dataframe.
netflix_data.drop_duplicates(inplace=True)

# %%
# Check there is no more duplicates.
netflix_data[netflix_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# # TASK 2: Is there any null value present in any column? Show with heat-map

# %%
# .isnull() method returns True when there is a missing value and False to indicate there is a non-missing 
# value.
netflix_data.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
# The last query it's not to representative. A mixture with .sum() will return the number of NaN values on 
# each column.
netflix_data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
# Now using the Seaborn library a heat map plot will make visual of how many missing values exist on the dataframe.

# sns.heatmap() function is primarily used to plot rectangular data as a color-encoded matrix. It allows to 
# visualize a 2D array or dataframe as a grid where each cell's color represents the value of the corresponding 
# element in the input data.
sns.heatmap(netflix_data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # TASK 3: In which year highest number the TV Shows and Movies where released? Show results with a bar graph.

# %%
# For this task it is needed to work with dates, so, a conversion from object to datetime data type.

# pd.to_datetime() function is incredibly useful when exist dates or times in various formats (e.g., strings or 
# numeric values) and are needed to convert into pandas datetime objects to perform various date and time 
# operations and manipulations.

# Result will be stored on a new column named ['Date_N']
netflix_data['Date_N'] = pd.to_datetime(netflix_data['Release_Date'], yearfirst=True)

# %%
# Check the dataframe with the new column
netflix_data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# Confirm the datatype
netflix_data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
# Next step consist on counting the occurrence of all individuals years in date column.

# dt.year attribute specifically allows accessing the year component of the datetime objects in the 
# Series or DataFrame column.

# Use value_counts() to count how many times each year are repeated.
netflix_data['Date_N'].dt.year.value_counts()
# Out:
# Date_N
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
# sns.countplot() function is specifically designed to create bar plots for categorical data and is used to 
# visualize the distribution of observations within a single categorical variable. 

# sns.set_context() function is used to set the context for the Seaborn plots, which controls the overall 
# appearance of the visualizations.

bar_graph = sns.countplot(data=netflix_data, x=netflix_data['Date_N'].dt.year, hue='Category', palette='Set1')
sns.set_context("poster", font_scale = 0.3, rc={"grid.linewidth": 0.6})
bar_graph.set_title('TV-Shows and Movies per year')
bar_graph.set_xlabel('Year')
bar_graph.set_ylabel('# of titles')
for label in bar_graph.containers:
    bar_graph.bar_label(label)
plt.show()

# %% [markdown]
# # TASK 4: How many movies and TV Shows are in the dataset? Show with bar grap

# %%
# Calling the dataframe
netflix_data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# Simply group the data by Category, and count how many records they have.
netflix_data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
# Countplot will be used similar as Task 3
bar_graph2 = sns.countplot(data=netflix_data, x=netflix_data['Category'], palette='Set2')
sns.set_context("poster", font_scale = 0.5, rc={"grid.linewidth": 0.6})
bar_graph2.set_title('TV-Shows vs Movies')
bar_graph2.set_xlabel('Category')
bar_graph2.set_ylabel('# of titles')
for label in bar_graph2.containers:
    bar_graph2.bar_label(label)
plt.show()

# %% [markdown]
# # TASK 5: Show all the movies released in year 2000

# %%
# Using dt.year a new column will be created to store the year
netflix_data['Year'] = netflix_data['Date_N'].dt.year

# %%
# Checking the result of the new column.
netflix_data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# For this task a filter will be used. The filter will be an AND.

# 1st condition: Categroy must be Movie.

# 2nd Condition: The year must be 2020.
netflix_data[(netflix_data['Category'] == 'Movie') & (netflix_data['Year'] == 2020)]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
# As mentioned, Jupyter notebook just shows the first 5 and last 5 records. So, to se the complete list it will 
# be stored on a secondary dataframe and then exporter into a diferent csv file.
netflix_2020_movies = netflix_data[(netflix_data['Category'] == 'Movie') & (netflix_data['Year'] == 2020)]

# %%
# to_csv is a method which exports the contents of the dataframe to a CSV (Comma Separated Values) file. 
netflix_2020_movies.to_csv('netflix2020movies_info.csv')

# %% [markdown]
# # TASK 6: Show only the titles of all TV Shows that were released in India

# %%
# Re-use the filter style from Task 5 , changing the category condition and the second argument of the condition.

# As it is asking to show only the title it is needed to be specified at the end ['Title'].
netflix_data[(netflix_data['Category'] == 'TV Show') & (netflix_data['Country'] == 'India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# # TASK 7: Show all the records, where Category is Movie and types is Comedies or Country is United Kingdom

# %%
# For this task a bigger filter will be used.

# First one an AND condition, to check movies and the type 'comedies'
netflix_data[(netflix_data['Category'] == 'Movie') & (netflix_data['Type'] == 'Comedies')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
# | symbol represents OR condition, will be added after the 2nd condition to look either comedies, or movies from 
# United Kingdom.
netflix_data[(netflix_data['Category'] == 'Movie') & (netflix_data['Type'] == 'Comedies') | (netflix_data['Country'] == 'United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# # TASK 8: In how many Movies / TV Shows Tom Cruise was cast?

# %%
# Filter Tom Cruise.

netflix_data[netflix_data['Cast']=='Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
# The previos filter showed nothing, right? This is because filtering in that way will only look for rows were only
# Tom Cruise appears. If there's another actor it wont' show anything, so a str.contains method will be used to 
# check if in the 'Cast' column 'Tom Cruise' appears somewhere.
netflix_data[netflix_data['Cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 4
#       1 # The previos filter showed nothing, right? This is because filtering in that way will only look for rows were only
#       2 # Tom Cruise appears. If there's another actor it wont' show anything, so a str.contains method will be used to
#       3 # check if in the 'Cast' column 'Tom Cruise' appears somewhere.
# ----> 4 netflix_data[netflix_data['Cast'].str.contains('Tom Cruise')]
#
# File c:\Users\raul_\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3751, in DataFrame.__getitem__(self, key)
#    3748     return self.where(key)
#    3750 # Do we have a (boolean) 1d indexer?
# -> 3751 if com.is_bool_indexer(key):
#    3752     return self._getitem_bool_array(key)
#    3754 # We are left with two options: a single key, and a collection of keys,
# ...

# %%
# It is showing an error, this is because if there exist a single NaN value all the command will be wrong. 

# .dropna() function allows to eliminate rows or columns containing missing values, which can be beneficial for 
# data cleaning and analysis. It helps to ensure that data is in a more consistent and usable format before 
# performing further operations.
netflix_new = netflix_data.dropna()

# %%
# Now it should show result this time.
netflix_new[netflix_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# # TASK 9: What are the different ratings defined by Netflix?

# %%
# .nunique()  function is particularly useful to find the count of distinct or unique values within a Series 
# or along a specific axis (rows or columns) of a dataframe.
netflix_data['Rating'].nunique()
# Out:
# 14

# %%
# To view the names, instead of finding the count it is needed to find the values. unique() function will be used 
# for that.
netflix_data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# # TASK 9.1: How many movies got the 'TV-14' rating in Canada?

# %%
# Use the same approach to the filters. First showing Movies and TV-14 query. At the end .shape works as the counter 
# this time.
netflix_data[(netflix_data['Rating'] == 'TV-14') & (netflix_data['Category'] == 'Movie')]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 15       s16    Movie                    oct-01      Kunle Afolayan
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7765   s7764    Movie                     Zenda      Avadhoot Gupte
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7770   s7769    Movie  Zindagi Kitni Haseen Hay       Anjum Shahzad
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast   Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...     India
# ...

# %%
# Afterwards the 3rd argument to show Canadian TV-14 Movies.
netflix_data[(netflix_data['Rating'] == 'TV-14') & (netflix_data['Category'] == 'Movie') & (netflix_data['Country'] == 'Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %%
# Finally, a count() method to return the number, and specifying to look only on ['Category'] column.
netflix_data[(netflix_data['Rating'] == 'TV-14') & (netflix_data['Category'] == 'Movie') & (netflix_data['Country'] == 'Canada')]['Category'].count()
# Out:
# 11

# %% [markdown]
# # TASK 9.2: How many TV Shows got the 'R' rating after 2018?

# %%
# Same approach as 9.1 task. First look the filter works.
netflix_data[((netflix_data['Rating'] == 'R') & (netflix_data['Category'] == 'TV Show')) & (netflix_data['Year'] > 2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date Rating  Duration      Type  \
# 6437  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description     Date_N    Year
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
# Finally the count of values.
netflix_data[((netflix_data['Rating'] == 'R') & (netflix_data['Category'] == 'TV Show')) & (netflix_data['Year'] > 2018)]['Category'].count()
# Out:
# 1

# %% [markdown]
# # TASK 10: What is the maximun duration of a Movie/ TV Show on Netlix?

# %%
# Calling the dataframe.
netflix_data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# It is showing 2 different measures. One is minutes (For movie) and Seasons (for tv-shows).

# str.split() unction is particularly useful to separate the strings into multiple parts or extract specific 
# information from a column. For example to split a comma-separated string into individual items.

# expand: If True, the result will be returned as a DataFrame with each split part in a separate column. If 
# False (default), the result will be returned as a Series with lists of split parts. For this expand will be
# true to create 2 columns: Quantity and Unit
netflix_data[['Quantity', 'Unit']] = netflix_data['Duration'].str.split(' ', expand=True)

# %%
# Check for the result
netflix_data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# Second step will be to convert the quantity values to integers (int) to apply the max() and min() function.

# astype() function convert the data type of elements to another type, such as changing numerical values to 
# strings or strings to integers.

# netflix_data.Quantity is the same as netflix_data['Quantity']
netflix_data.Quantity = netflix_data.Quantity.astype(int)

# %%
# Another issue arises. max() and min() function will look just numbers, but there are 2 different unist of 
# measurement.
# To ensure that the methods will work for each category movie and tv-show. Filtering season and min and saved 
# them into a separated dataframe resepectively will be the next step.
netflix_seasons = netflix_data[netflix_data['Unit'] == 'Seasons']
netflix_minutes = netflix_data[netflix_data['Unit'] == 'min']

# %%
# Finally, looking into 'Quantity' column from seasons, the maximun value can be found.
netflix_seasons['Quantity'].max()
# Out:
# 16

# %%
# Then, in minutes dataframe
netflix_minutes.Quantity.max()
# Out:
# 312

# %% [markdown]
# # TASK 11: Which country has the Highest No. of TV Shows ?

# %%
# Using the seasons dataframe, a value_counts() method can return how many each country has.
netflix_seasons.Country.value_counts().head(5)
# Out:
# Country
# United States     333
# United Kingdom     75
# Japan              56
# Canada             39
# Australia          19
# Name: count, dtype: int64

# %% [markdown]
# # TASK 12: What is the distribution of content ratings (e.g., Rated R, PG-13, PG) on Netflix, and which rating category has the highest number of titles?

# %%
# Time to call the dataframe to refresh the info.
netflix_data.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# Using the count values will display how many titles each category has.
netflix_data['Rating'].value_counts()
# Out:
# Rating
# TV-MA       2863
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: count, dtype: int64

# %%
# Using the same type of graphic from previous tasks the info will be displayed accordingly.
bar_graph3 = sns.countplot(data=netflix_data, x=netflix_data['Rating'], palette='Set3')
sns.set_context("poster", font_scale = 0.3, rc={"grid.linewidth": 0.6})
bar_graph3.set_title('Content Rating Distribution')
bar_graph3.set_xlabel('Rating')
bar_graph3.set_ylabel('# of titles')
for label in bar_graph3.containers:
    bar_graph3.bar_label(label)
plt.show()

# %% [markdown]
# # TASK 13: What is the distribution from Type of content across TV-MA rating?

# %%
# Save a secondary dataframe which store only TV-MA rating titles
netflix_tv_ma_rating = netflix_data[netflix_data['Rating'] == 'TV-MA']

# %%
# Checking the new dataframe
netflix_tv_ma_rating.head(10)
# Out:
#    Show_Id Category     Title              Director  \
# 0       s1  TV Show        3%                   NaN
# 1       s2    Movie     07:19     Jorge Michel Grau
# 5       s6  TV Show        46           Serdar Akar
# 6       s7    Movie       122       Yasir Al Yasiri
# 9      s10    Movie      1920          Vikram Bhatt
# 10     s11    Movie      1922          Zak Hilditch
# 11     s12  TV Show      1983                   NaN
# 12     s13  TV Show      1994  Diego Enrique Osorno
# 13     s14    Movie     2,215   Nottapon Boonprakob
# 26     s27  TV Show  (Un)Well                   NaN
#
#                                                  Cast                Country  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...                 Brazil
# 1   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...                 Mexico
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...                 Turkey
# 6   Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...                  Egypt
# ...

# %%
# In 'Type' there is a particullary, one movie can appear in more than 1 type. If the count stays with that form
# Dramas, Thrillers will be a different type as Dramas only. So is needed to make that movie appear in 3 individual
# types.

# Split the combined types into individual types
netflix_tv_ma_rating['Type'] = netflix_tv_ma_rating['Type'].str.split(', ')
# Out:
# C:\Users\raul_\AppData\Local\Temp\ipykernel_13984\2845399202.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_tv_ma_rating['Type'] = netflix_tv_ma_rating['Type'].str.split(', ')

# %%
# Create a new DataFrame to store the individual types.
individual_types_df = netflix_tv_ma_rating.explode('Type')

# %%
# Count the occurrences of each individual type and print them.
individual_types_df['Type'].value_counts()
# Out:
# Type
# International Movies            983
# Dramas                          720
# International TV Shows          621
# TV Dramas                       397
# Comedies                        374
# Crime TV Shows                  314
# Independent Movies              310
# Documentaries                   287
# Stand-Up Comedy                 281
# TV Comedies                     245
# Thrillers                       209
# Action & Adventure              181
# Docuseries                      156
# Horror Movies                   147
# Romantic Movies                 132
# Romantic TV Shows               114
# Spanish-Language TV Shows       105
# Music & Musicals                102
# British TV Shows                 96
# TV Action & Adventure            73
# Reality TV                       71
# Sports Movies                    65
# TV Mysteries                     61
# TV Horror                        53
# LGBTQ Movies                     53
# Sci-Fi & Fantasy                 50
# ...
